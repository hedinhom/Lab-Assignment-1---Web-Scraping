# %%
 Alsowmali Ahmed Mohammed ObadSW01083243
Mohamed isameldin sw01083173
# Out:
# /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages/IPython/core/inputtransformer2.py:608: UserWarning: `make_tokens_by_line` received a list of lines which do not have lineending markers ('\n', '\r', '\r\n', '\x0b', '\x0c'), behavior will be unspecified
#   tokens_by_line = make_tokens_by_line(lines)
#   Cell In[1], line 1
#     Alsowmali Ahmed Mohammed Obad
#                                  ^
# SyntaxError: invalid non-printable character U+2028

# %%
# ====================================================
# CISB5123 Text Analytics - Lab Assignment 1
# Name: Alsowmali Ahmed Mohammed Obad
# Student ID: SW01083243
#
# This script scrapes 5 pages of eBay product reviews
# and extracts:
# - Reviewer Name
# - Review Date
# - Review Content
# Then saves the data to CSV.
# ====================================================
